# %% [markdown]
# # Task 02 – Data Cleaning & Exploratory Data Analysis on Titanic Dataset
#
# ### Objective
# Perform data cleaning and exploratory data analysis (EDA) on a Titanic-style dataset to explore relationships between variables and identify patterns.

# %% [markdown]
# Step 1 : Loading Data

# %%
# Load Data
import pandas as pd

df = pd.read_csv("mock_titanic_dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass         Name     Sex        Age  SibSp  \
# 0            1         0       3  Passenger 1    male   0.000000      2
# 1            2         1       3  Passenger 2    male  61.073196      1
# 2            3         1       2  Passenger 3  female   9.545985      2
# 3            4         0       3  Passenger 4  female   5.964418      3
# 4            5         0       3  Passenger 5  female  43.315986      3
#
#    Parch  Ticket       Fare Cabin Embarked
# 0      0  T97265  44.447759   NaN        S
# 1      0  T41131  12.109346   NaN        Q
# 2      2  T62428  58.489240   NaN        Q
# 3      2  T43870  43.952467   NaN        Q
# 4      0  T59067  42.925947   B20        S

# %% [markdown]
# Step 2 : Cleaning Data

# %%
# Check missing values
df.isnull().sum()

# Fill missing values
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df['Cabin'] = df['Cabin'].fillna('Unknown')

# %% [markdown]
# Step 3 : Exploratory Data Analysis

# %%
# Survival Count
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Survived', hue='Survived', palette='Set2', legend=False)
plt.title("Survival Count")
plt.xlabel("Survived")
plt.ylabel("Count")
plt.show()

# %%
# Survival by Gender
sns.countplot(data=df, x='Sex', hue='Survived', palette='coolwarm')
plt.title("Survival by Gender")
plt.show()

# %%
# Survival by Class
sns.countplot(data=df, x='Pclass', hue='Survived', palette='Set1')
plt.title("Survival by Passenger Class")
plt.show()

# %%
# Age Distribution by Survival
sns.histplot(data=df, x='Age', hue='Survived', multiple='stack', bins=20)
plt.title("Age Distribution by Survival")
plt.show()

# %%
# Correlation Matrix
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Blues')
plt.title("Correlation Heatmap")
plt.show()
